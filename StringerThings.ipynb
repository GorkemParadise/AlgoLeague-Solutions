# %%
a = int(input().strip())
b = input().strip()

my_list = [b[0]]
for i in range(1, a):
    if b[i] != b[i-1]:
        my_list.append(b[i])

print("".join(my_list))
# Out:
# APKL

# %%
a
# Out:
# 8

# %%
b
# Out:
# 'AAAPPKKL'

# %%
my_list
# Out:
# ['A', 'P', 'K', 'L']
